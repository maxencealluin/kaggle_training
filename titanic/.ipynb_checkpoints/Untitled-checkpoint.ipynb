# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
import math
import numpy as np

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

X_train = train.loc[:, train.columns != 'Survived']
X_test = train.loc[:, train.columns != 'Survived']
Y_train = train.loc[:, train.columns == 'Survived']

dfs = [X_train, X_test]

# %%
dfs[0].describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594   32.204208
# std     257.353842    0.836071   14.526497    1.102743    0.806057   49.693429
# min       1.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000   31.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
group_by = train.loc[:, train.columns != 'PassengerId'].groupby(by = 'Survived')

# %%
group_by.mean().plot(kind='bar')
sbn.lmplot("Age", "Fare", data=train, hue="Survived", fit_reg=False, col = "Embarked", col_wrap = 3)

# %%
for i, df in enumerate(dfs):
    dummies = pd.get_dummies(df.loc[:, ['Embarked', 'Pclass', 'Sex']].astype(str), drop_first = True)
    df['cabin_known'] = df['Cabin'].isnull() == True
    df['age_known'] = df['Age'].isnull() == True
    mean_age = df.loc[df['Age'].isnull() == False, 'Age'].mean()
    df['Age'].fillna(mean_age, inplace = True)
    df = df.join(dummies)
    dfs[i] = df

# %%
for df in dfs:
    df.drop(['Ticket', 'Embarked', 'Pclass', 'Sex', 'Name','Cabin', 'PassengerId'], axis=1, inplace = True)

# %%
classifiers = {}

from sklearn.ensemble import RandomForestClassifier
classifiers['random_forest'] = RandomForestClassifier(random_state=42, n_estimators=200)

# %%
from sklearn.metrics import *
from sklearn.model_selection import KFold


for key, classifier in classifiers.items():
    classifier.fit(dfs[0], np.ravel(Y_train))
    Y_pred = classifier.predict(dfs[0])
    print("Training accuracy: " + str(accuracy_score(Y_train, Y_pred)))
    kfold = KFold(n_splits = 10, random_state = 42)
# Out:
# Training accuracy: 0.9865319865319865
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-59c432df40ee> in <module>
#       7     Y_pred = classifier.predict(dfs[0])
#       8     print("Training accuracy: " + str(accuracy_score(Y_train, Y_pred)))
# ----> 9     kfold = KFold(folds = 10, random_state = 42)
#
# TypeError: __init__() got an unexpected keyword argument 'folds'
